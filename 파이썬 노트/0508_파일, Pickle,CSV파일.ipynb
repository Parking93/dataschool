# %% [markdown]
# # 1. 파일
#
# * 파일은 컴퓨터를 실행할때 가장 기본이 되는 단위.
# * 보통 프로그램실행할때 파일을 실행한다 라고 여김.
# * 그 중의 우리는 csv, excel, txt, .py 파일을 사용한다.

# %%
# 1. 파일 읽기 예제

# f = open('파일명', '파일열기 모드')
# f.close()

# 파일 여는 모드는 읽기, 쓰기, 추가 등등이 있음
# 읽기모드 -> r / 쓰기 -> w / 추가 -> a

f = open('song.txt', 'w')
f.write('''
다 잊었다는 거짓말 또 해버렸죠
내 마음에 그대란 사람 없다고 했죠
너무나 쉽게 잊혀졌다고 이젠 남이라고
서툰 내 사랑에
지쳐 떠난 그대
너무 많이 울려서
잡을 용기조차 낼 수 없었죠
미안해요 내 사랑아
다신 나 같은 사람 만나지 마요
혹시 찾아가도 두 번 다시
나를 허락해주지 마요
그댄 여리고 너무 착해서
싫단 말도 잘 못하는데
많이 부족한 나를 사랑한 그대
이거면 됐어요 더 이상은
그대 불행하지 않도록
나 이쯤에서 없어지는 게
그댈 위한 나의 사랑인걸요
너무 투명해서
때론 불안했죠
제멋대로 살아온
나를 감당할 수 없을 거 같죠
미안해요 내 사랑아
다신 나 같은 사람 만나지 마요
혹시 찾아가도 두 번 다시
나를 허락해주지 마요
그댄 여리고 너무 착해서
싫단 말도 잘 못하는데
고마웠어요 나를 사랑해줘서
나 같은 사람이 두 번 다시
감히 받을 수 없는 사랑
그대 때문에 행복했어요
울지 마요 그대
잘 생각해 봐요
나쁜 일들만 가득했던 우리
다 잊어야 해요
많이 부족한 나를 사랑한 그대
이거면 됐어요 더 이상은 그대
불행하지 않도록
나 이쯤에서 없어지는 게
그댈 위한 나의 사랑인걸요
''')
f.close()

# %%
f = open('song.txt', 'r')
data = f.read()
print(data)
f.close()

# 1행에서 open()함수 다음에 파일명 다음에 읽기 모드 r을 입력해서 파일에 대한 값을 f에 저장
# 2행에서 f를 이용해서 Read()함수를 실행하면 해당 파일의 텍스트들이 contents에 할당이 되고
# Out:
# 다 잊었다는 거짓말 또 해버렸죠
# 내 마음에 그대란 사람 없다고 했죠
# 너무나 쉽게 잊혀졌다고 이젠 남이라고
# 서툰 내 사랑에
# 지쳐 떠난 그대
# 너무 많이 울려서
# 잡을 용기조차 낼 수 없었죠
# 미안해요 내 사랑아
# 다신 나 같은 사람 만나지 마요
# 혹시 찾아가도 두 번 다시
# 나를 허락해주지 마요
# 그댄 여리고 너무 착해서
# 싫단 말도 잘 못하는데
# 많이 부족한 나를 사랑한 그대
# 이거면 됐어요 더 이상은
# 그대 불행하지 않도록
# 나 이쯤에서 없어지는 게
# 그댈 위한 나의 사랑인걸요
# 너무 투명해서
# 때론 불안했죠
# 제멋대로 살아온
# 나를 감당할 수 없을 거 같죠
# 미안해요 내 사랑아
# 다신 나 같은 사람 만나지 마요
# 혹시 찾아가도 두 번 다시
# 나를 허락해주지 마요
# 그댄 여리고 너무 착해서
# 싫단 말도 잘 못하는데
# 고마웠어요 나를 사랑해줘서
# 나 같은 사람이 두 번 다시
# 감히 받을 수 없는 사랑
# 그대 때문에 행복했어요
# 울지 마요 그대
# 잘 생각해 봐요
# 나쁜 일들만 가득했던 우리
# 다 잊어야 해요
# 많이 부족한 나를 사랑한 그대
# 이거면 됐어요 더 이상은 그대
# 불행하지 않도록
# 나 이쯤에서 없어지는 게
# 그댈 위한 나의 사랑인걸요

# %%
# with문

# with을 활용해서 Open() 함수를 대체할 수 있다.
# with문은 들여쓰기를 잘해야한다. 함수 if
# 결론적으로 close()문을 안쓰는 편리함이 있음.
with open('song.txt', 'r') as my_song_list:
    content = my_song_list.read()
    print(content)
# Out:
# 다 잊었다는 거짓말 또 해버렸죠
# 내 마음에 그대란 사람 없다고 했죠
# 너무나 쉽게 잊혀졌다고 이젠 남이라고
# 서툰 내 사랑에
# 지쳐 떠난 그대
# 너무 많이 울려서
# 잡을 용기조차 낼 수 없었죠
# 미안해요 내 사랑아
# 다신 나 같은 사람 만나지 마요
# 혹시 찾아가도 두 번 다시
# 나를 허락해주지 마요
# 그댄 여리고 너무 착해서
# 싫단 말도 잘 못하는데
# 많이 부족한 나를 사랑한 그대
# 이거면 됐어요 더 이상은
# 그대 불행하지 않도록
# 나 이쯤에서 없어지는 게
# 그댈 위한 나의 사랑인걸요
# 너무 투명해서
# 때론 불안했죠
# 제멋대로 살아온
# 나를 감당할 수 없을 거 같죠
# 미안해요 내 사랑아
# 다신 나 같은 사람 만나지 마요
# 혹시 찾아가도 두 번 다시
# 나를 허락해주지 마요
# 그댄 여리고 너무 착해서
# 싫단 말도 잘 못하는데
# 고마웠어요 나를 사랑해줘서
# 나 같은 사람이 두 번 다시
# 감히 받을 수 없는 사랑
# 그대 때문에 행복했어요
# 울지 마요 그대
# 잘 생각해 봐요
# 나쁜 일들만 가득했던 우리
# 다 잊어야 해요
# 많이 부족한 나를 사랑한 그대
# 이거면 됐어요 더 이상은 그대
# 불행하지 않도록
# 나 이쯤에서 없어지는 게
# 그댈 위한 나의 사랑인걸요

# %%
# 한줄로 읽어오는 방법
# 파일 전체의 텍스트를 문자열로 반환하는 read()대신에 readlines()함수를 사용하면
# 한줄의 기준은 \n

with open('song.txt', 'r') as my_song_list:
    content_list = my_song_list.readlines()
    print(content_list)
# Out:
# ['\n', '다 잊었다는 거짓말 또 해버렸죠\n', '내 마음에 그대란 사람 없다고 했죠\n', '너무나 쉽게 잊혀졌다고 이젠 남이라고\n', '서툰 내 사랑에\n', '지쳐 떠난 그대\n', '너무 많이 울려서\n', '잡을 용기조차 낼 수 없었죠\n', '미안해요 내 사랑아\n', '다신 나 같은 사람 만나지 마요\n', '혹시 찾아가도 두 번 다시\n', '나를 허락해주지 마요\n', '그댄 여리고 너무 착해서\n', '싫단 말도 잘 못하는데\n', '많이 부족한 나를 사랑한 그대\n', '이거면 됐어요 더 이상은\n', '그대 불행하지 않도록\n', '나 이쯤에서 없어지는 게\n', '그댈 위한 나의 사랑인걸요\n', '너무 투명해서\n', '때론 불안했죠\n', '제멋대로 살아온\n', '나를 감당할 수 없을 거 같죠\n', '미안해요 내 사랑아\n', '다신 나 같은 사람 만나지 마요\n', '혹시 찾아가도 두 번 다시\n', '나를 허락해주지 마요\n', '그댄 여리고 너무 착해서\n', '싫단 말도 잘 못하는데\n', '고마웠어요 나를 사랑해줘서\n', '나 같은 사람이 두 번 다시\n', '감히 받을 수 없는 사랑\n', '그대 때문에 행복했어요\n', '울지 마요 그대\n', '잘 생각해 봐요\n', '나쁜 일들만 가득했던 우리\n', '다 잊어야 해요\n', '많이 부족한 나를 사랑한 그대\n', '이거면 됐어요 더 이상은 그대\n', '불행하지 않도록\n', '나 이쯤에서 없어지는 게\n', '그댈 위한 나의 사랑인걸요\n']

# %%
content_list[2]
# Out:
# '내 마음에 그대란 사람 없다고 했죠\n'

# %%
with open('song.txt', 'r') as my_song_list:
    while True:
        line = my_song_list.readline()
        if not line:
            break
        print(line.replace("\n", ""))
# Out:
# 다 잊었다는 거짓말 또 해버렸죠
# 내 마음에 그대란 사람 없다고 했죠
# 너무나 쉽게 잊혀졌다고 이젠 남이라고
# 서툰 내 사랑에
# 지쳐 떠난 그대
# 너무 많이 울려서
# 잡을 용기조차 낼 수 없었죠
# 미안해요 내 사랑아
# 다신 나 같은 사람 만나지 마요
# 혹시 찾아가도 두 번 다시
# 나를 허락해주지 마요
# 그댄 여리고 너무 착해서
# 싫단 말도 잘 못하는데
# 많이 부족한 나를 사랑한 그대
# 이거면 됐어요 더 이상은
# 그대 불행하지 않도록
# 나 이쯤에서 없어지는 게
# 그댈 위한 나의 사랑인걸요
# 너무 투명해서
# 때론 불안했죠
# 제멋대로 살아온
# 나를 감당할 수 없을 거 같죠
# 미안해요 내 사랑아
# 다신 나 같은 사람 만나지 마요
# 혹시 찾아가도 두 번 다시
# 나를 허락해주지 마요
# 그댄 여리고 너무 착해서
# 싫단 말도 잘 못하는데
# 고마웠어요 나를 사랑해줘서
# 나 같은 사람이 두 번 다시
# 감히 받을 수 없는 사랑
# 그대 때문에 행복했어요
# 울지 마요 그대
# 잘 생각해 봐요
# 나쁜 일들만 가득했던 우리
# 다 잊어야 해요
# 많이 부족한 나를 사랑한 그대
# 이거면 됐어요 더 이상은 그대
# 불행하지 않도록
# 나 이쯤에서 없어지는 게
# 그댈 위한 나의 사랑인걸요

# %%
song_list_new = []

with open('song.txt', 'r') as my_song_list:

    while True:
        line = my_song_list.readline()
        if not line:
            break
        song_list_new.append(line.replace("\n", ""))

# %%
song_list_new
# Out:
# ['',
#  '다 잊었다는 거짓말 또 해버렸죠',
#  '내 마음에 그대란 사람 없다고 했죠',
#  '너무나 쉽게 잊혀졌다고 이젠 남이라고',
#  '서툰 내 사랑에',
#  '지쳐 떠난 그대',
#  '너무 많이 울려서',
#  '잡을 용기조차 낼 수 없었죠',
#  '미안해요 내 사랑아',
#  '다신 나 같은 사람 만나지 마요',
#  '혹시 찾아가도 두 번 다시',
#  '나를 허락해주지 마요',
#  '그댄 여리고 너무 착해서',
#  '싫단 말도 잘 못하는데',
#  '많이 부족한 나를 사랑한 그대',
#  '이거면 됐어요 더 이상은',
#  '그대 불행하지 않도록',
#  '나 이쯤에서 없어지는 게',
#  '그댈 위한 나의 사랑인걸요',
#  '너무 투명해서',
#  '때론 불안했죠',
#  '제멋대로 살아온',
#  '나를 감당할 수 없을 거 같죠',
#  '미안해요 내 사랑아',
#  '다신 나 같은 사람 만나지 마요',
#  '혹시 찾아가도 두 번 다시',
#  '나를 허락해주지 마요',
#  '그댄 여리고 너무 착해서',
#  '싫단 말도 잘 못하는데',
#  '고마웠어요 나를 사랑해줘서',
#  '나 같은 사람이 두 번 다시',
#  '감히 받을 수 없는 사랑',
#  '그대 때문에 행복했어요',
#  '울지 마요 그대',
#  '잘 생각해 봐요',
#  '나쁜 일들만 가득했던 우리',
#  '다 잊어야 해요',
#  '많이 부족한 나를 사랑한 그대',
#  '이거면 됐어요 더 이상은 그대',
#  '불행하지 않도록',
#  '나 이쯤에서 없어지는 게',
#  '그댈 위한 나의 사랑인걸요']

# %%
with open('song.txt','r') as my_song_list:
    contents = my_song_list.read()
    word_list = contents.split(" ")
    line_list = contents.split("\n")

print(f"총 글자수는 {len(contents)}입니다.")
print(f"총 단어수는 {len(word_list)}입니다.")
print(f"총 줄수는 {len(line_list)}입니다.")
# Out:
# 총 글자수는 556입니다.
# 총 단어수는 122입니다.
# 총 줄수는 43입니다.

# %%
### 파일 쓰기

# 앞서 파일쓰기 중에서 utf-8/ cp949/euc-kr

# 인코딩 실습

f = open('count_list.txt', 'w', encoding = 'utf-8')

# %%
for i in range(1, 11):
    data = f'{i}번째 입니다.'
    f.write(data)
f.close()

# %%
with open('count_list_new.txt', 'w', encoding = 'utf-8') as f:
    for i in range(1, 11):
        data = f'{i}번째 입니다.'
        f.write(data)

# %% [markdown]
# # Pickle

# %%
# Pickle 모듈

# 파이썬 프로그램을 실행할때마다 변수 객체를 메모리에 저장하고,
# 컴퓨터를 껐다가 켜면 모두 날라갑니다.

# 파이썬은 pickle모듈을 제공합니다.
# 메모리에 로딩된 객체들을 연속적으로 사용할 수 있게 

# 데이터, 클래스, 함수, 프로그램을 저장할 수 있음.

# 향후 대기업, 관련 빅데이터 플랫폼 활용.

# %%
# pickle 모듈을 사용하려면 import 저장하고자하는 객체를 넘기면됩니다.

# 지금까지 파일을 열때 r 파일을 쓸때 w
# pickle 에서는 파일을 열대 rb 파일을 쓸때 wb

# %%
import pickle

# %%
f = open('list.pickle', 'wb')
test = [1, 2, 3, 4, 5]
pickle.dump(test, f)
f.close()

# %%
f = open('list.pickle', 'rb')
test_pickle = pickle.load(f)
print(test_pickle)
# Out:
# [1, 2, 3, 4, 5]

# %%
# pickle은 클래스도 저장가능하다.

class Multiply(object):
    def __init__(self, multi):
        self.multi = multi
    def multiply(self, number):
        return number * self.multi

multi_test = Multiply(5)
multi_test.multiply(10)
# Out:
# 50

# %%
f = open('multiply_object.pickle', 'wb')
pickle.dump(multi_test, f)
f.close()

# %%
f = open('multiply_object.pickle', 'rb')
multi_test = pickle.load(f)
multi_test.multiply(50)
# Out:
# 250

# %% [markdown]
# # CSV 데이터
#
# * csv 쉼표로 나눠진 데이터인데
# 1,2,3,4,5 -> test.csv/txt
# * .xlax 보다 .csv가 더 많이 사용된다.
# * 읽기에도 좋고, 용량도 excel파일보다 작고, 콤마로 구분되어 있어서 사용하기 편하거나 전처리하기 좋다.
# * python -> excel -> python

# %% [markdown]
# * 데이터 분석의 대부분은 통계프로그램이 아니라 아직은 엑셀 작업을 주로합니다;
# * 그만큼 우리는 스트레드시트 데이터를 많이 보게됩니다.
# * excel만 잘 다뤄도 데이터분석 잘한다소리들음;

# %%
import csv 

import os # 경로지정

# %%
# 경로 지정 

os.chdir('/content/sample_data')

# %%
# open 

f = open('test.csv' ,'r' ,encoding = 'utf-8')
new = csv.reader(f)

# %%
list(new)
# Out:
# [['국어', '영어', '수학', '', '', '', ''], ['50', '80', '90', '', '', '', '']]

# %%
# csv파일 출력하기

a_list = []
for i in new:
    print(i)
    a_list.append(i)
f.close()

# %%
# 함수화 하기

def opencsv(filename):
    f = open(filename, 'r')
    reader = csv.reader(f)
    output = []
    for i in reader:
        output.append(i)
    f.close()
    return output
opencsv('test.csv')
# Out:
# [['국어', '영어', '수학', '', '', '', ''], ['50', '80', '90', '', '', '', '']]

# %%
# 새로운 데이터 읽기 예제

a = [['구', '전체', '내국인', '외국인'], 
     ['관악구','519864','502089','17775'], 
     ['강남구','547602','542498','5104'], 
     ['송파구','686181', '679247', '6934'], 
     ['강동구','428547','424235','4312']]

# %%
a
# Out:
# [['구', '전체', '내국인', '외국인'],
#  ['관악구', '519864', '502089', '17775'],
#  ['강남구', '547602', '542498', '5104'],
#  ['송파구', '686181', '679247', '6934'],
#  ['강동구', '428547', '424235', '4312']]

# %%
f = open('abc.csv', 'w', newline ='')
new_csv = csv.writer(f, delimiter = ',')
new_csv.writerows(a) # a자료를 csv 파일에 넣기
f.close()

# %%
# 새로운 데이터 읽기 예제

b = [['구', '전체', '내국인', '외국인'], 
     ['관악구','519864','502089','17775'], 
     ['강남구','547602','542498','5104'], 
     ['송파구','686181', '679247', '6934'], 
     ['강동구','428547','424235','4312']]

# %%
# 함수화 하기
def writecsv(filename, list):
    with open(filename, 'w', newline = '') as f:
        a = csv.writer(f, delimiter = ',')
        a.writerows(list)

# %%
writecsv('new_abc.csv', b)

# %% [markdown]
# # 0509

# %%
# 경로 지정 
import os 
os.chdir('/content')

# %%
# seoul.csv 활용

# %%
import csv

# %%
# 함수화 하기
def opencsv(filename):
    f = open(filename, 'r')
    reader = csv.reader(f)
    output = []
    for i in reader:
        output.append(i)
    return output

# %%
total = opencsv('seoul.csv')

# %%
# 상위 5개 파일 불러오기 head() 상위 5개 불러오기
for i in total [:5]:
  print(i)
# Out:
# ['Gu', 'Korean', 'Foreigner', 'Senior']
# ['Total', '9,740,398', '285,529', '1,468,146']
# ['Jongrogu', '151,767', '11,093', '27,394']
# ['Jongru', '126,409', '10,254', '23,025']
# ['Yongsangu', '228,830', '16,159', '38,531']

# %%
# 숫자형이 문자형으로 되어있는 경우
# '9,740,398'

i = '123'
float(i)

# %%
int(i)

# %%
#문자형을 실수형으로 바꿀때 ,가 있으면 에러가 납니다.
float('123,456')

# %%
import re

# %%
# substring -> 슬라이싱

# sub -> 대체 -> 한다

j = '123,456'
float(re.sub(',', '', j)) # sub(바꿔야하는거, 바꿀것,데이터)
# Out:
# 123456.0

# %%
int(re.sub(',','',j))
# Out:
# 123456

# %%
# 슬라이싱
total[:5]
# Out:
# [['Gu', 'Korean', 'Foreigner', 'Senior'],
#  ['Total', '9,740,398', '285,529', '1,468,146'],
#  ['Jongrogu', '151,767', '11,093', '27,394'],
#  ['Jongru', '126,409', '10,254', '23,025'],
#  ['Yongsangu', '228,830', '16,159', '38,531']]

# %%
# 인덱싱
i = total[2]
i
# Out:
# ['Jongrogu', '151,767', '11,093', '27,394']

# %%
# 만약, 문자와 숫자가섞여있다면?
# 데이터가 밀리는 경우는 부지기수.

p = ['123강남구', '456종로구', '11,093', '27,394']
k = []
for j in p:
  if re.search('[a-z가-힣]', j): #j에서 알파멧 또는 문자가 있다면
    k.append(j)
  else:
    k.append(float(re.sub(',' , '', j)))
