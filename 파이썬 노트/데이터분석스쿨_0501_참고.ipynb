# %% [markdown]
# # 강의 노트 (김진환 강사님)

# %% [markdown]
# ## 파이썬 코드

# %% [markdown]
# * 1. 들여쓰기는 공백 문자 네 개로 하자.
# * 2. 한줄의 최대 글자는 79자로 한다.
# * 3. 최상위 함수와 클래스 정의들은 두 줄씩 띄우자.
# * 4. 파일은 UTF-8 또는 아스키(ASCII)로 인코딩하자.
# * 5. 한 import 문에선 모듈 하나만 불러온다.
# * 6. 소괄호나 중괄호, 대괄호 사이에 추가로 공백을 주지 말고, 쉼표 안에도 공백을 주지 말자,
# * 7. 클래스 이름은 카멜케이스(CamelCase)를 따르자.
# * 8. 예외명은 Error로 끝내자.
# * 9. 함수 이름은 separated_by_underscores처럼 소문자와 밑줄 문자(_)를 이용해서 짓자.
# * 10. 비공개인 속성이나 메서드 이름은 밑줄 문자로 시작하자(_private).

# %%
# 1. 주석 복습

# 1.1.1 주석 실습 - 예제 1

# 행단 위 주석입니다.

'''
큰 따옴표로 세번 묶거나 
작은 따옴표로 세번 묶으면
열 단위 주석이 됩니다.
'''

print('Hello world')

# %% [markdown]
# ### 블럭 주석
# * 바로 뒤에 오는 코드를 설명하고
# * 주석 내용이 다루는 코드와 동일한 들여쓰기 레벨에서 표기한다.
# * 한개의 #을 달고 주석을 기록한다.

# %%
# 유저의 이름을 입력받고, 문자형이 아닌것을 주의하세요.
user_input = input("유저 이름을 입력하세요")
normalized_data = normalizednormalize_data(user_inputs)

# %% [markdown]
# ### 인라인 주석
#
# * 코드와 같은 줄에 기록
# * #을 붙인 후 내용 기록
# * 코드와 적어도 두칸 이상 분리한다.

# %%
연봉_인센포함 = 초기연봉 * 1.02   # 초기연봉에 2% 상승된 것이 인센포함된 연봉(23.05.01) 변경시 수정 바람

# %% [markdown]
# ### 문서 형태 주석

# %% [markdown]
# * 모듈, 클래스, 함수, 메소드 등 정보를 제공하는 용도 docstring이라고 함
# * 다른 주석과 달리 쌍따옴표나 따움표 3개로 구성
# * 함수 바로 밑에 내용을 적는다.
# * 여러줄로도 적을수 있다.

# %%
# 문서 주석 - 한줄 형태

def quicksort():
""" Quicksort를 사용하여 보다 빠르게 정렬하는 함수 """

#1.1.3 문서 주석 - 두줄 이상 형태

def salary_increase(salary, percentage, rating):
    """ 성과에 의한 연봉 변화 함수
    1 - 2등급 - 연봉 10% 상승
    3 - 4등급 - 연봉 5%  상승
    5 - 6등급 - 연봉 동결
    7 - 10등급 - 연봉 5% 삭감
    """

# %% [markdown]
# ### 레이아웃

# %% [markdown]
# [임포트]
# * import는 가장 위에 기록 한다.
# * 한줄에 하나씩 쓰는것을 추천한다.
#
# [들여쓰기]
# * 들여쓰기는 4칸씩 띄어쓰기를 꼭 지킨다. - Tab을 활용해도 되지만 통일 필요 (수업때는 Tab)
# * 함수의 줄 바꿈시에는 구분이 가능하도록 한다.
#
# [탭과 스페이스]
# * 탭보다는 스페이스를 사용하도록 노력하고, 섞어서 쓰지 말자
#
# [글자 길이 / 줄 바꿈]
# * 주석은 72자정도 / 최대 글자수는 79자 정도로 제한하는 것이 좋음
#
# [빈줄 넣기]
# * 일반적으로 클래스나 함수는 두줄로 분리해서 구분하기 좋게 한다.
# * 그러나 클래스나 함수 안에 함수는 논리적으로 구분이 되는 부분에서 한줄을 띄워도 좋다.
#
# [연산하는 경우]
# * 연산을 많이 할 경우에는 옆으로 글을 이어나가는 것보다는 밑으로 추가한다.)

# %%
# import 예시

# 좋은 예
import os
import pandas as pd
import sklearn

# 안좋은 예시

import os, sys, pandas
from pandas import * # wildcard 사용은 소스의 모호함을 증가시켜 오류를 발생시킬수도 있음

# %%
# 띄어쓰기 / # 2.3 탭과 스페이스

# 기본 띄어쓰기 - 둘다 실행은 된다.
for i in range(1, 10):
  print(i) # Tab

for i in range(1, 10):
    print(i) # 띄어쓰기 4칸 

# 파라미터가 여러가지 인 경우
# 좋은 예시
sample_def(var1, var2
          var3, var4) #일반적인 툴에서는 다음과 같이 enter를 사용하는 경우 띄어지게 된다.

# 안좋은 예시 - 가독성이 떨어진다.
sample_def(var1, var2
  var3, var4)

# %%
# 연산하는 경우
# 좋은 예시
sum_variable = (val1
                + val2
                +_val3
                + val4
)

# %% [markdown]
# ### 파이썬 스타일 작명

# %% [markdown]
# [상수]
# * 이름이 길어지면 underbar(_)로 구분한다.
# * 대문자로 작성
#
# [패키지/모듈]
# * 가급적 짧고 알기 쉽게 만든다.
# * 패키지나 모듈 이름은 모두 소문자로만 작성한다.
# * 모듈 이름이 만약 길어지면 underbar(_)로 구분한다.
# * 패키지 이름에는 underbar사용 자제
#
# [클래스]
# * 클래스 이름은 CamelCase(단어 첫부분은 대문자)로 작성
#
# [메소드]
# * 메소드 이름은 snake_tail방식으로 작성하고 단어별 underbar(_)로 구분한다.
# * 인스턴스 메소드의 첫번째인자는 항상 self로 시작한다.
# * 클래스 메소드의 첫번째 인자는 항상 cls로 시작한다.

# %%
# 왠만하면 한글을 사랑해도 한글 변수명은 자제

# 상수/함수/변수

#[상수] 모두 대문자
PI = 3.14
LONG_CONSTANT_EXAMPLE = 12345678

#[함수/변수]
#snake case
my_age = 43

(good) def python_function_name(arg1, arg2):
(bad) def PythonFunctionName(arg1, arg2):

# 모듈 (snake case 허용)
# 패키지 이름
(good) import mypackage
(good) import modulename
(bad) import ModuleName
(bad) import module_name



# 클래스(Pascal case)
# Class 예
class MyClass:
    pass

# 메소드
class MyClass:
  '''인스턴스 메소드 메소드'''
  def instance_method(self, var1, var2):
    pass

  '''클래스 메소드'''
  def class_method(cls, var1, var2):
    pass

# %% [markdown]
# ### 공백문자

# %%
# 할당

# Good

x = 1
y = 2
long_variable = 3

# Bad

x             = 1
y             = 2
long_variable = 3

# 앞 뒤로 공백 1개씩

# Good

i = i + 1
submitted += 1
x = x*2 - 1

# Bad 

i=i+1
submitted +=1
x = x * 2 - 1

# 괄호, 콜론 앞/뒤로는 공백을 주지 않습니다.

# Good
router(1)
router[1:3]
server['centOs']
Class MyClass:

# bad

router (1)
router[1: 3]
server ['centos']
Class MyRouter :

# %% [markdown]
# ## Chat GPT

# %%
# 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

# %%
pip install openai
# Out:
# Looking in indexes: https://pypi.org/simple, https://us-python.pkg.dev/colab-wheels/public/simple/
# Collecting openai
#   Downloading openai-0.27.5-py3-none-any.whl (71 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 71.6/71.6 kB 6.0 MB/s eta 0:00:00
# Collecting aiohttp
#   Downloading aiohttp-3.8.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (1.0 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.0/1.0 MB 49.0 MB/s eta 0:00:00
# Requirement already satisfied: tqdm in /usr/local/lib/python3.10/dist-packages (from openai) (4.65.0)
# Requirement already satisfied: requests>=2.20 in /usr/local/lib/python3.10/dist-packages (from openai) (2.27.1)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2022.12.7)
# Requirement already satisfied: charset-normalizer~=2.0.0 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (2.0.12)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (1.26.15)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.10/dist-packages (from requests>=2.20->openai) (3.4)
# Collecting yarl<2.0,>=1.0
#   Downloading yarl-1.9.2-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (268 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 268.8/268.8 kB 24.7 MB/s eta 0:00:00
# Collecting async-timeout<5.0,>=4.0.0a3
#   Downloading async_timeout-4.0.2-py3-none-any.whl (5.8 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.0.4-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (114 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 114.5/114.5 kB 13.9 MB/s eta 0:00:00
# Collecting aiosignal>=1.1.2
#   Downloading aiosignal-1.3.1-py3-none-any.whl (7.6 kB)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.10/dist-packages (from aiohttp->openai) (23.1.0)
# Collecting frozenlist>=1.1.1
#   Downloading frozenlist-1.3.3-cp310-cp310-manylinux_2_5_x86_64.manylinux1_x86_64.manylinux_2_17_x86_64.manylinux2014_x86_64.whl (149 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 149.6/149.6 kB 14.9 MB/s eta 0:00:00
# Installing collected packages: multidict, frozenlist, async-timeout, yarl, aiosignal, aiohttp, openai
# Successfully installed aiohttp-3.8.4 aiosignal-1.3.1 async-timeout-4.0.2 frozenlist-1.3.3 multidict-6.0.4 openai-0.27.5 yarl-1.9.2

# %%
import os
import openai

# %%
# Open AI API key 추가

openai.api_key = "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"

question = input("무엇을 물어볼까요?:")

completion = openai.ChatCompletion.create(
  model="gpt-3.5-turbo",
  messages=[
    {"role": "user", "content": question}
  ]
)

print(completion.choices[0].message.content)
# Out:
# 무엇을 물어볼까요?:gpt
# GPT stands for “Generative Pre-trained Transformer”. It is a deep learning algorithm developed by OpenAI that is capable of generating natural language text that is human-like and coherent. GPT is based on the transformer architecture and has been pre-trained on large amounts of text data, enabling it to generate high-quality language output. GPT is used in a variety of applications, such as language translation, chatbots, and text completion tools.

# %%
def chat_gpt(message):
  openai.api_key ="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" #아까 복사했던 api 주소를 " " 안에 넣습니다.
  
  completion = openai.ChatCompletion.create(
    model="gpt-3.5-turbo",
    messages=[
      {"role": "user", "content": message}
    ]
  )
  return(print(completion.choices[0].message.content))

chat_gpt("gpt란 뭐야?")
# Out:
# GPT는 "Generative Pre-training Transformer"의 약어로, OpenAI에서 개발한 자연어 처리 인공지능 모델입니다. 이 모델은 대규모 텍스트 데이터를 학습하여 문장 생성, 요약, 번역, 질문응답 등 다양한 자연어 처리 작업을 수행할 수 있습니다. GPT 시리즈는 2018년 GPT-1부터 2020년 GPT-3까지 개발되었으며, 2021년에는 DALL-E와 GPT-Neo가 발표되었습니다. GPT는 인공지능 분야에서 가장 대표적이고 성능이 뛰어난 언어 모델 중 하나입니다.

# %% [markdown]
# ## 기본 입출력
#
# * 변수 - X = 10이라는 코드가 있을때 10을 x로 할당한다고 한다. 변수에는 숫자, 문자등 다양한 자료형태가 들어갈수 있으며, 자료형태 확인은 type함수를 통해 확인할 수 있다.
# * input - input()함수로 데이터를 입력하면 자료를 입력받는 함수 - 기본으로는 문자형을 입력받는다.
# * print - print()함수로 데이터를 출력하는 함수

# %%
my_name = input()
print(f'제 이름은 {my_name} 입니다.')
# Out:
# 제 이름은  입니다.

# %%
sum_1 = input('첫번째 숫자를 입력하세요. ')
sum_2 = input('두번째 숫자를 입력하세요. ')

# input은 기본적으로 문자형을 받기 때문에 숫자형쓰고 싶으면 int(), float() 사용.
print(sum_1 + sum_2)
print(int(sum_1) + int(sum_2))
# Out:
# 첫번째 숫자를 입력하세요. 20
# 두번째 숫자를 입력하세요. 30
# 2030
# 50

# %%
# print()
name = '박재혁'
age = 30
print(f'제 이름은 {name} 이고, 나이는 {age}입니다.')
# Out:
# 제 이름은 박재혁 이고, 나이는 30입니다.

# %%
# 기본 입출력 복습 
# 실습 
#1. () -> 변수
#2. f-string으로 작성
#3. print()문으로 출력 

# 안녕하세요 저는 ()입니다. 나이는 ()입니다.
# 저의 MBTI는 ()입니다. 제 성격은 ()입니다.
# 저의 전공은 ()이고, 관심분야는 ()입니다.
# 제가 취업하고 싶은 기업은 ()이고, 원하는 연봉은 ()원입니다.
# 마지막으로 제가 하고 싶은 말은? ()입니다.

# %%
name = '박재혁'
age = 31
major = '통계학과'
mbti = 'ESFP'
personality = '활발'
interesting = '데이터분석'
company = '고민중입니다.'
salary = '다다익선'
a = '화이팅화이팅' 

print(f'안녕하세요 저는 {name}. 나이는 {age} 입니다.')
print(f'저의 MBTI')

# %%
# 숫자를 문자열로 바꾸기

ex1 = 52
ex1_str = str(52)

print(f"ex1은 {ex1}입니다.")
print(f"ex1은 {ex1_str}입니다.")

print(type(ex1))
print(type(ex1_str))

# 문자를 숫자로 바꾸기

ex2_str_int = int(ex1_str)

print(f"ex1_str은 {ex1_str}입니다.")
print(f"ex2_str_int은 {ex2_str_int}입니다.")

print(type(ex1_str))
print(type(ex2_str_int))

# %%
# 문자열 자르기 : split()

a = "10 20 30 40 50".split(" ")  # split은 리스트로 반환되기 때문에 매우 유용하다.
print(a)

# %%
# 문자열과 In 연산자

print("멋쟁이" in "멋쟁이 사자처럼")
print("위니브" in "멋쟁이 사자처럼")

# %%
# 문자열과 find함수
ex3 = "멋쟁이 사자처럼"
print(ex3.find("사자"))

# %%
# 공백 제거 
# txt, csv -> python "멋쟁이 사자처럼" -> "  멋쟁이 사자처럼"
ex4 = "   안녕하세요 멋쟁이 사자처럼 입니다."

print(ex4.strip())

# %% [markdown]
# ## Random 함수의 활용
#
# * 데이터 분석시에 무작위 테스트를 하거나 샘플을 뽑고 싶을때 사용 (굉장히 많이 사용)

# %%
# Random 함수 사용
import random

# %%
# 1. random 함수의 기본 사용

random.random()
# Out:
# 0.2589453524188836

# %%
# 어디서부터 어디까지의 숫자를 뽑아줘. (실수)

random.uniform(1, 10)
# Out:
# 4.52217706522184

# %%
# 어디서부터 어디까지의 숫자를 뽑아줘. (정수)
random.randint(1, 10) # 1 ~ 10까지 무작위 수.
# Out:
# 9

# %%
# Choice
random.choice('Hello')
# Out:
# 'l'

# %%
random.choice(['바나나', '오렌지', '사과'])
# Out:
# '바나나'

# %%
# 랜덤하게 여러 원소를 출력합니다.
random.sample([1,2,3,4,5],3) # 리스트중에 3개를 뽑을거야.
# Out:
# [2, 4, 1]

# %%
random.sample(range(1, 5), 3) # 위와 동일
# Out:
# [1, 4, 2]

# %%
# 실습 1. 로또번호 1~45번까지 6개 번호 추출해보기

random.sample(range(1,46), 6)
# Out:
# [44, 6, 18, 5, 37, 25]

# %%
# shuffle 함수 

items = [1, 2, 3, 4, 5]
random.shuffle(items)
print(items)
# Out:
# [3, 1, 4, 5, 2]

# %%
# seed 고정 

random.seed(501)
lotto = random.sample(range(1, 46), 6)

print(f'로또번호 : {lotto}')
# Out:
# 로또번호 : [41, 19, 45, 23, 16, 21]

# %%
# 실습 2. 보드게임 주사위 2개 던지기 -> 난수 추점

die1 = random.randint(1, 6)
die2 = random.randint(1, 6)

print(f'주사위 합 : {die1 + die2}')
# Out:
# 주사위 합 : 8

# %%
# 실습 3. 오늘의 점심 메뉴
# -> 리스트로 가져와서 오늘 먹을 점심메뉴를 선택하는 랜덤 프로그램 작성

오늘점심메뉴 = ['돈까스', '제육볶음', '샐러드', '고등어조림', '김치찌개']
print(f'오늘의 점심 메뉴 : {random.choice(오늘점심메뉴)}')
# Out:
# 오늘의 점심 메뉴 : 돈까스

# %%
# 실습 4. 가위바위보
# 컴퓨터가 낸거는 랜덤

computer = random.choice(['가위','바위','보'])
me = input('무엇을 내실건가요?')
print(f'나 : {me}')
print(f'컴퓨터 : {computer}')
# Out:
# 무엇을 내실건가요?가위
# 나 : 가위
# 컴퓨터 : 가위

# %%
# 실습 4. 가위바위보 (함수)
# 컴퓨터가 낸거는 랜덤
def 가위바위보() :
    computer = random.choice(['가위','바위','보자기'])
    me = input('무엇을 내실건가요?')
    print(f'나 : {me}')
    print(f'컴퓨터 : {computer}')
    if me == computer :
        print('무승부!')
    elif me == '보자기' and computer == '가위' :
        print('당신이 지셨습니다.')
    elif me == '바위' and computer == '보자기' :
        print('당신이 지셨습니다.')
    elif me == '가위' and computer == '바위' :
        print('당신이 지셨습니다.')
    else :
        print('당신이 이겼습니다.')

가위바위보()
# Out:
# 무엇을 내실건가요?가위
# 나 : 가위
# 컴퓨터 : 보자기
# 당신이 이겼습니다.

# %% [markdown]
# ## 시간 함수

# %%
# time 함수 
import time

# %%
time.time()
# Out:
# 1682908383.4550374

# %%
time.ctime() # 미국 시간
# Out:
# 'Mon May  1 02:33:39 2023'

# %%
time.localtime()
# Out:
# time.struct_time(tm_year=2023, tm_mon=5, tm_mday=1, tm_hour=2, tm_min=33, tm_sec=47, tm_wday=0, tm_yday=121, tm_isdst=0)

# %%
# datetime 함수
import datetime

# %%
datetime.datetime
# Out:
# datetime.datetime

# %%
from datetime import datetime

# %%
now = datetime.now()
now
# Out:
# datetime.datetime(2023, 5, 1, 2, 36, 21, 152455)

# %%
# 현재 시간
print(f'현재 시간은 {now.time()}')
# 현재 날짜
print(f'현재 날짜는 {now.date()}')
# 현재 월
print(f'현재 월은 {now.month}')
# 현재 일
print(f'현재 일은 {now.day}')
# 현재 연도
print(f'현재 연도는 {now.year}')

# 시 hour 분 minute 초 second 요일 weekend
# Out:
# 현재 시간은 11:52:21.462800
# 현재 날짜는 2023-05-01
# 현재 월은 5
# 현재 일은 1
# 현재 연도는 2023

# %%
import pytz

datetime.now(pytz.timezone('UTC'))
# Out:
# datetime.datetime(2023, 5, 1, 2, 52, 10, 41111, tzinfo=<UTC>)

# %%
datetime.now(pytz.timezone('Asia/Seoul'))
# Out:
# datetime.datetime(2023, 5, 1, 11, 52, 10, 463733, tzinfo=<DstTzInfo 'Asia/Seoul' KST+9:00:00 STD>)

# %%
from datetime import timedelta, timezone
datetime.now(timezone(timedelta(hours=9)))
# Out:
# datetime.datetime(2023, 5, 1, 11, 52, 11, 419456, tzinfo=datetime.timezone(datetime.timedelta(seconds=32400)))

# %%
from datetime import datetime
from datetime import timedelta, timezone


now = datetime.now(timezone(timedelta(hours=9)))

print("현재 : ", now)
print("현재 날짜 : ", now.date())
print("현재 시간 : ", now.time())
print("timestamp : ", now.timestamp())
print("년 : ", now.year)
print("월 : ", now.month)
print("일 : ", now.day)
print("시 : ", now.hour)
print("분 : ", now.minute)
print("초 : ", now.second)
print("마이크로초 : ", now.microsecond)
print("요일 : ", now.weekday())
print("문자열 변환 : ", now.strftime('%Y-%m-%d %H:%M:%S'))

# Output
# 현재 :  2021-12-22 15:46:26.695840
# 현재 날짜 :  2021-12-22
# 현재 시간 :  15:46:26.695840
# timestamp :  1640155586.69584
# 년 :  2021
# 월 :  12
# 일 :  22
# 시 :  15
# 분 :  46
# 초 :  26
# 마이크로초 :  695840
# 요일 :  2
# 문자열 변환 :  2021-12-22 15:46:26
# Out:
# 현재 :  2023-05-01 11:52:12.671730+09:00
# 현재 날짜 :  2023-05-01
# 현재 시간 :  11:52:12.671730
# timestamp :  1682909532.67173
# 년 :  2023
# 월 :  5
# 일 :  1
# 시 :  11
# 분 :  52
# 초 :  12
# 마이크로초 :  671730
# 요일 :  0
# 문자열 변환 :  2023-05-01 11:52:12

# %% [markdown]
# ## 파이썬 멈추기

# %%
import time # sleep 함수 사용

# %%
# 1. 초 단위 테스트
print('-' * 30)
now = datetime.now(timezone(timedelta(hours=9)))
print(now.strftime('%H:%M:%S')) # 현재 시간 출력

time.sleep(5) # 5 초 딜레이

now = datetime.now(timezone(timedelta(hours=9)))
print(now.strftime('%H:%M:%S'))

time.sleep(10) # 10 초 딜레이

print(datetime.now().strftime('%H:%M:%S'))
# Out:
# ------------------------------
# 11:52:16
# 11:52:21
# 02:52:31

# %%
chat_gpt('파이썬 연산에 딜레이를 주는 프로그램이 뭐야?')
# Out:
# 파이썬에서 딜레이를 주는 함수는 time 모듈의 sleep() 함수입니다.
#
# 예를 들어, 다음과 같이 사용할 수 있습니다.
#
# ```
# import time
#
# print("첫 번째 줄")
# time.sleep(2)
# print("두 번째 줄")
# ```
#
# 위 코드는 "첫 번째 줄"을 출력한 후 2초간 딜레이를 준 다음 "두 번째 줄"을 출력합니다. 딜레이 시간은 인자로 전달된 초 단위 값을 기반으로 합니다.

# %%
chat_gpt('파이썬에서 한국시간으로 time을 설정하는 프로그램은뭐야?')
# Out:
# 다음은 파이썬에서 한국시간으로 time을 설정하는 예제 코드입니다.
#
# ```python
# import datetime
# import pytz
#
# kst = pytz.timezone('Asia/Seoul') # 한국 표준시간대 객체 생성
#
# now = datetime.datetime.now(kst) # 현재 시간을 한국 시간대로 설정
#
# print(now.strftime('%Y-%m-%d %H:%M:%S')) # 현재 시간 출력 (년-월-일 시:분:초)
# ```
#
# 해당 코드를 실행하면 현재 시간이 한국 시간대로 출력됩니다. 예를 들어, 현재 시간이 2021년 8월 20일 오후 4시 30분 10초라면 다음과 같은 결과가 출력됩니다.
#
# ```
# 2021-08-20 16:30:10
# ```

# %% [markdown]
# ## 파이썬 프로그램 시간 측정

# %%
from time import process_time 
start = time.time() # 측정 시작

end = time.time()
print('프로그램을 수행하는데', end - start, '초가 걸렸습니다.')
# Out:
# 프로그램을 수행하는데 2.8848648071289062e-05 초가 걸렸습니다.

# %%
from time import process_time
start = time.time() # 측정 시작
print("★ 구구단을 출력합니다.\n")
for x in range(2, 10):
    print("------- [" + str(x) + "단] -------")
    for y in range(1, 10):
        print(x, "X", y, "=", x*y)
print("---------------------")
end = time.time() # 측정이 여기까지
print('프로그램을 수행하는데', end - start, '초가 걸렸습니다.')
# Out:
# ★ 구구단을 출력합니다.
#
# ------- [2단] -------
# 2 X 1 = 2
# 2 X 2 = 4
# 2 X 3 = 6
# 2 X 4 = 8
# 2 X 5 = 10
# 2 X 6 = 12
# 2 X 7 = 14
# 2 X 8 = 16
# 2 X 9 = 18
# ------- [3단] -------
# 3 X 1 = 3
# 3 X 2 = 6
# 3 X 3 = 9
# 3 X 4 = 12
# 3 X 5 = 15
# 3 X 6 = 18
# 3 X 7 = 21
# 3 X 8 = 24
# 3 X 9 = 27
# ------- [4단] -------
# 4 X 1 = 4
# 4 X 2 = 8
# 4 X 3 = 12
# 4 X 4 = 16
# 4 X 5 = 20
# 4 X 6 = 24
# 4 X 7 = 28
# 4 X 8 = 32
# 4 X 9 = 36
# ------- [5단] -------
# 5 X 1 = 5
# 5 X 2 = 10
# 5 X 3 = 15
# 5 X 4 = 20
# 5 X 5 = 25
# 5 X 6 = 30
# 5 X 7 = 35
# 5 X 8 = 40
# 5 X 9 = 45
# ------- [6단] -------
# 6 X 1 = 6
# 6 X 2 = 12
# 6 X 3 = 18
# 6 X 4 = 24
# 6 X 5 = 30
# 6 X 6 = 36
# 6 X 7 = 42
# 6 X 8 = 48
# 6 X 9 = 54
# ------- [7단] -------
# 7 X 1 = 7
# 7 X 2 = 14
# 7 X 3 = 21
# 7 X 4 = 28
# 7 X 5 = 35
# 7 X 6 = 42
# 7 X 7 = 49
# 7 X 8 = 56
# 7 X 9 = 63
# ------- [8단] -------
# 8 X 1 = 8
# 8 X 2 = 16
# 8 X 3 = 24
# 8 X 4 = 32
# 8 X 5 = 40
# 8 X 6 = 48
# 8 X 7 = 56
# 8 X 8 = 64
# 8 X 9 = 72
# ------- [9단] -------
# 9 X 1 = 9
# 9 X 2 = 18
# 9 X 3 = 27
# 9 X 4 = 36
# 9 X 5 = 45
# 9 X 6 = 54
# 9 X 7 = 63
# 9 X 8 = 72
# 9 X 9 = 81
# ---------------------
# 프로그램을 수행하는데 0.10843491554260254 초가 걸렸습니다.

# %%
start = process_time()
print("★ 구구단을 출력합니다.\n")
for x in range(2, 10):
    print("------- [" + str(x) + "단] -------")
    for y in range(1, 10):
        print(x, "X", y, "=", x*y)
print("---------------------")
end = process_time()
print('프로그램을 수행하는데', end - start, '초가 걸렸습니다.')
# Out:
# ★ 구구단을 출력합니다.
#
# ------- [2단] -------
# 2 X 1 = 2
# 2 X 2 = 4
# 2 X 3 = 6
# 2 X 4 = 8
# 2 X 5 = 10
# 2 X 6 = 12
# 2 X 7 = 14
# 2 X 8 = 16
# 2 X 9 = 18
# ------- [3단] -------
# 3 X 1 = 3
# 3 X 2 = 6
# 3 X 3 = 9
# 3 X 4 = 12
# 3 X 5 = 15
# 3 X 6 = 18
# 3 X 7 = 21
# 3 X 8 = 24
# 3 X 9 = 27
# ------- [4단] -------
# 4 X 1 = 4
# 4 X 2 = 8
# 4 X 3 = 12
# 4 X 4 = 16
# 4 X 5 = 20
# 4 X 6 = 24
# 4 X 7 = 28
# 4 X 8 = 32
# 4 X 9 = 36
# ------- [5단] -------
# 5 X 1 = 5
# 5 X 2 = 10
# 5 X 3 = 15
# 5 X 4 = 20
# 5 X 5 = 25
# 5 X 6 = 30
# 5 X 7 = 35
# 5 X 8 = 40
# 5 X 9 = 45
# ------- [6단] -------
# 6 X 1 = 6
# 6 X 2 = 12
# 6 X 3 = 18
# 6 X 4 = 24
# 6 X 5 = 30
# 6 X 6 = 36
# 6 X 7 = 42
# 6 X 8 = 48
# 6 X 9 = 54
# ------- [7단] -------
# 7 X 1 = 7
# 7 X 2 = 14
# 7 X 3 = 21
# 7 X 4 = 28
# 7 X 5 = 35
# 7 X 6 = 42
# 7 X 7 = 49
# 7 X 8 = 56
# 7 X 9 = 63
# ------- [8단] -------
# 8 X 1 = 8
# 8 X 2 = 16
# 8 X 3 = 24
# 8 X 4 = 32
# 8 X 5 = 40
# 8 X 6 = 48
# 8 X 7 = 56
# 8 X 8 = 64
# 8 X 9 = 72
# ------- [9단] -------
# 9 X 1 = 9
# 9 X 2 = 18
# 9 X 3 = 27
# 9 X 4 = 36
# 9 X 5 = 45
# 9 X 6 = 54
# 9 X 7 = 63
# 9 X 8 = 72
# 9 X 9 = 81
# ---------------------
# 프로그램을 수행하는데 0.12196151400000588 초가 걸렸습니다.
