# %% [markdown]
# # Pandas
#
# - 데이터 자체를 분석, 파악
# - 표
# - 데이터 다루는 데 초점
# - 정렬, 필터링, 그룹화, 집계

# %% [markdown]
# - 데이터 불러오기 및 저장
# - 데이터 인덱싱 및 슬라이싱
# - 결측치 처리
# - 데이터 변환
# - 데이터 집계 및 그룹화
#
# ---
# - 시계열 데이터 처리
# - 데이터 시각화 (데이터 자체가 어떻게 생겼는지)

# %% [markdown]
# 1. Series(시리즈)
# 2. DataFrame(데이터 프레임)

# %% [markdown]
# ## 1. Series(시리즈)
#
# - 인덱스를 지정할 수 있음

# %%
import pandas as pd

# %%
s = pd.Series([1, 2, 3, 4]) # 리스트 
print(s)
# Out:
# 1

# %%
s2 = pd.Series({'a': 1, 'b': 2, 'c': 3, 'd': 4}) # 딕셔너리 
print(s2)
# Out:
# a    1
# b    2
# c    3
# d    4
# dtype: int64
# (4,)

# %%
s3 = pd.Series(5, index = [0, 1, 2]) # 스칼라로 시리즈를 만드는 방법 인덱스의 개수 만큼 스칼라의 개수가 생성 된다. 
print(s3)
# Out:
# 0    5
# 1    5
# 2    5
# dtype: int64

# %%
# 활용 
data = [1, 2, 3, 4, 5]
index = ['a', 'b', 'c', 'd', 'e']
series_data = pd.Series(data, index = index) 
print(series_data)
# Out:
# a    1
# b    2
# c    3
# d    4
# e    5
# dtype: int64

# %%
s = pd.Series(data)
print(s)
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64

# %% [markdown]
# ###**슬라이싱**

# %%
series = pd.Series([1, 2, 3, 4, 5])
series[:4]
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %% [markdown]
# ###**Boolean indexing**

# %%
series = pd.Series([1, 2, 3, 4, 5])
series[series > 2]
# Out:
# 0    False
# 1    False
# 2     True
# 3     True
# 4     True
# dtype: bool

# %%
# 5보다 작은 시리즈

series[series < 5]
# Out:
# 0    1
# 1    2
# 2    3
# 3    4
# dtype: int64

# %% [markdown]
# ### 산술연산

# %%
series = pd.Series([1, 2, 3, 4, 5])

# 덧셈
print(f'series + 100 : \n{series + 100}')
# 뺄셈
print(f'series - 100 : \n{series - 100}')

# 곱셈
print(f'series * 100 : \n{series * 100}')

# 나눗셈
print(f'series / 100 : \n{series / 100}')

# 제곱
print(f'series ** 100 : \n{series ** 100}')

# 나머지
print(f'series % 100 : \n{series % 100}')

# 몫 
print(f'series // 100 : \n{series // 100}')
# Out:
# series + 100 :
# 0    101
# 1    102
# 2    103
# 3    104
# 4    105
# dtype: int64
# series - 100 :
# 0   -99
# 1   -98
# 2   -97
# 3   -96
# 4   -95
# dtype: int64
# series * 100 :
# 0    100
# 1    200
# 2    300
# 3    400
# 4    500
# dtype: int64
# series / 100 :
# 0    0.01
# 1    0.02
# 2    0.03
# 3    0.04
# 4    0.05
# dtype: float64
# series ** 100 :
# 0                      1
# 1                      0
# 2   -2984622845537545263
# 3                      0
# 4   -3842938066129721103
# dtype: int64
# series % 100 :
# 0    1
# 1    2
# 2    3
# 3    4
# 4    5
# dtype: int64
# series // 100 :
# 0    0
# 1    0
# 2    0
# 3    0
# 4    0
# dtype: int64

# %% [markdown]
# ### Series 객체에 접근
#
# - Keys
# - values

# %%
s2 = pd.Series({'a': 1, 'b': 2, 'c': 3, 'd': 4}) # 딕셔너리 

print(s2.keys())
print(s2.values)
print(s2.index)
# Out:
# Index(['a', 'b', 'c', 'd'], dtype='object')
# [1 2 3 4]
# Index(['a', 'b', 'c', 'd'], dtype='object')

# %%
series = pd.Series([1, 2, 3, 4, 5])
print(series.keys())
print(series.index)
print(series.values)
print(series[0])
# Out:
# RangeIndex(start=0, stop=5, step=1)
# RangeIndex(start=0, stop=5, step=1)
# [1 2 3 4 5]
# 1

# %%
# items
print(s2.items()) # zip -> 순회가 가능, 쌍으로 이루어져있음.

# %%
for index, value in s2.items():
    print(f'인덱스 : {index}, values : {value}')
# Out:
# 인덱스 : a, values : 1
# 인덱스 : b, values : 2
# 인덱스 : c, values : 3
# 인덱스 : d, values : 4

# %%
s = pd.Series([10, 20, 30, 40], index = ['a', 'b', 'c', 'd'])
print(s)
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64

# %%
print(s.loc['b']) # loc: 행에 접근 -> 레이블(특정 인덱스)에 접근하기 위해서 
print(s.loc['b':'d'])
# Out:
# 20
# b    20
# c    30
# d    40
# dtype: int64

# %%
print(s.iloc[1]) # iloc: (행에 기반한) 열에 접근
# Out:
# 20

# %%
print(s.at['a']) # at loc 비슷, 하나의 값만 가져올 때
# Out:
# 10
# 10

# %%
print(s.iat[0])  # at에 기반
# Out:
# 10

# %%
print(s.get('e')) # 없는 값에 대한 처리 방법 , 없을 때 에러가 나지않고 None을 출력 
print(s.get('e', default = -1)) # 없는 것이 있다면 -1로 출력해주세요.
# Out:
# None
# -1

# %%
print(s)
print(s['a'])
print(s.loc['a'])
print(s.get('a'))
print(s.at['a'])
print(s.iloc[0])
# Out:
# a    10
# b    20
# c    30
# d    40
# dtype: int64
# 10
# 10
# 10
# 10
# 10

# %% [markdown]
# ### 결측값 (NaN, None)
#
# * isna()
# * isnull()
#
#
# Nan(Not a number) -> float
#
# None -> None

# %%
import numpy as np
import pandas as pd

# %%
data = [1, 2, 3, None]

print(np.array(data))
# Out:
# [1 2 3 None]

# %%
print(pd.Series(data))
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    NaN
# dtype: float64

# %%
s = pd.Series(data)
print(s.isna())
print(s.isnull())
# Out:
# 0    False
# 1    False
# 2    False
# 3     True
# dtype: bool
# 0    False
# 1    False
# 2    False
# 3     True
# dtype: bool

# %%
# 빈 값이 총 몇개인지 확인하는 방법 
print(s.isna().sum())
print(s.isnull().sum())
# Out:
# 1
# 1

# %%
print(s.notnull().sum())
# Out:
# 3

# %% [markdown]
# **결측치제거**

# %%
s.dropna()
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# dtype: float64

# %%
# 결측치를 0으로 치환

s.fillna(0)
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    0.0
# dtype: float64

# %%
# 결측치를 1로 치환
s.fillna(1)
# Out:
# 0    1.0
# 1    2.0
# 2    3.0
# 3    1.0
# dtype: float64

# %% [markdown]
# ### series 함수

# %%
s = pd.Series([1, 3, 5, 7, 9])

print(s.count()) # 카운트 함수 
print(s.min())
print(s.max())
print(s.mean())
print(s.std())
print(s.var())
# Out:
# 5
# 1
# 9
# 5.0
# 3.1622776601683795
# 10.0
